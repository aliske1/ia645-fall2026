# %% [markdown]
# # IA 645 — Lab 6
# **Name:**
# **Date:**
# **Dataset:**

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# Your code below

# %% [markdown]
# ## Findings and Observations
# Document what you found, what it means, and any anomalies you identified.
